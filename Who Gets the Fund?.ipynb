# %% [markdown]
# **Plan**
#
# Question
# 1. Which model can best predict whether or not you will get a Kickstarter funding?
# 2. Which "live" projects will likely be funded?
#
# Steps:
# 1. Acquire and Prep
# 2. Explore
#     - Which features are the strongest predictors of funding? (Feature selection)
#     - Out of the ones that received funding, which ones are over funded and underfunded?
# 3. Model
# 4. Evaluate

# %% [markdown]
# ### Packages

# %%
import wrangle
import pandas as pd

# %% [markdown]
# ## Acquire

# %% [markdown]
# Read csv file from local repo using `get_kickstarter` function from `wrangle.py`.

# %%
def get_kickstarter():
    df = pd.read_csv("/Users/cris/codeup-data-science/kickstarter_project/kickstarter.csv")
    return df

# %%
org = pd.read_csv("/Users/cris/codeup-data-science/kickstarter_project/countryContinent.csv",encoding="latin-1")

# %%
states = pd.read_csv("/Users/cris/codeup-data-science/kickstarter_project/us_states.csv",encoding="latin-1")

# %%
org.head()
# Out:
#           country code_2 code_3  country_code     iso_3166_2 continent  \
# 0     Afghanistan     AF    AFG             4  ISO 3166-2:AF      Asia
# 1   Åland Islands     AX    ALA           248  ISO 3166-2:AX    Europe
# 2         Albania     AL    ALB             8  ISO 3166-2:AL    Europe
# 3         Algeria     DZ    DZA            12  ISO 3166-2:DZ    Africa
# 4  American Samoa     AS    ASM            16  ISO 3166-2:AS   Oceania
#
#         sub_region  region_code  sub_region_code
# 0    Southern Asia        142.0             34.0
# 1  Northern Europe        150.0            154.0
# 2  Southern Europe        150.0             39.0
# 3  Northern Africa          2.0             15.0
# 4        Polynesia          9.0             61.0

# %%
org = org.rename(columns={"country":"origin"})

# %%
org = org[["origin","continent","sub_region"]]

# %%
org
# Out:
#                                                 origin continent  \
# 0                                          Afghanistan      Asia
# 1                                        Åland Islands    Europe
# 2                                              Albania    Europe
# 3                                              Algeria    Africa
# 4                                       American Samoa   Oceania
# 5                                              Andorra    Europe
# 6                                               Angola    Africa
# 7                                             Anguilla  Americas
# 8                                           Antarctica       NaN
# 9                                  Antigua and Barbuda  Americas
# 10                                           Argentina  Americas
# 11                                             Armenia      Asia
# 12                                               Aruba  Americas
# 13                                           Australia   Oceania
# 14                                             Austria    Europe
# 15                                          Azerbaijan      Asia
# 16                                             Bahamas  Americas
# 17                                             Bahrain      Asia
# 18                                          Bangladesh      Asia
# 19                                            Barbados  Americas
# 20                                             Belarus    Europe
# 21                                             Belgium    Europe
# 22                                              Belize  Americas
# 23                                               Benin    Africa
# 24                                             Bermuda  Americas
# 25                                              Bhutan      Asia
# 26                    Bolivia (Plurinational State of)  Americas
# 27                    Bonaire, Sint Eustatius and Saba  Americas
# 28                              Bosnia and Herzegovina    Europe
# 29                                            Botswana    Africa
# ..                                                 ...       ...
# 219                       Tanzania, United Republic of    Africa
# 220                                           Thailand      Asia
# 221                                        Timor-Leste      Asia
# 222                                               Togo    Africa
# 223                                            Tokelau   Oceania
# 224                                              Tonga   Oceania
# 225                                Trinidad and Tobago  Americas
# 226                                            Tunisia    Africa
# 227                                             Turkey      Asia
# 228                                       Turkmenistan      Asia
# 229                           Turks and Caicos Islands  Americas
# 230                                             Tuvalu   Oceania
# 231                                             Uganda    Africa
# 232                                            Ukraine    Europe
# 233                               United Arab Emirates      Asia
# 234  United Kingdom of Great Britain and Northern I...    Europe
# 235                           United States of America  Americas
# 236               United States Minor Outlying Islands       NaN
# 237                                            Uruguay  Americas
# 238                                         Uzbekistan      Asia
# 239                                            Vanuatu   Oceania
# 240                 Venezuela (Bolivarian Republic of)  Americas
# 241                                           Viet Nam      Asia
# 242                           Virgin Islands (British)  Americas
# 243                              Virgin Islands (U.S.)  Americas
# 244                                  Wallis and Futuna   Oceania
# 245                                     Western Sahara    Africa
# 246                                              Yemen      Asia
# 247                                             Zambia    Africa
# 248                                           Zimbabwe    Africa
#
#                     sub_region
# 0                Southern Asia
# 1              Northern Europe
# 2              Southern Europe
# 3              Northern Africa
# 4                    Polynesia
# 5              Southern Europe
# 6                Middle Africa
# 7                    Caribbean
# 8                          NaN
# 9                    Caribbean
# 10               South America
# 11                Western Asia
# 12                   Caribbean
# 13   Australia and New Zealand
# 14              Western Europe
# 15                Western Asia
# 16                   Caribbean
# 17                Western Asia
# 18               Southern Asia
# 19                   Caribbean
# 20              Eastern Europe
# 21              Western Europe
# 22             Central America
# 23              Western Africa
# 24            Northern America
# 25               Southern Asia
# 26               South America
# 27                   Caribbean
# 28             Southern Europe
# 29             Southern Africa
# ..                         ...
# 219             Eastern Africa
# 220         South-Eastern Asia
# 221         South-Eastern Asia
# 222             Western Africa
# 223                  Polynesia
# 224                  Polynesia
# 225                  Caribbean
# 226            Northern Africa
# 227               Western Asia
# 228               Central Asia
# 229                  Caribbean
# 230                  Polynesia
# 231             Eastern Africa
# 232             Eastern Europe
# 233               Western Asia
# 234            Northern Europe
# 235           Northern America
# 236                        NaN
# 237              South America
# 238               Central Asia
# 239                  Melanesia
# 240              South America
# 241         South-Eastern Asia
# 242                  Caribbean
# 243                  Caribbean
# 244                  Polynesia
# 245            Northern Africa
# 246               Western Asia
# 247             Eastern Africa
# 248             Eastern Africa
#
# [249 rows x 3 columns]

# %%
states = states[["State","Code"]]
states.head()
# Out:
#         State Code
# 0     Alabama   AL
# 1      Alaska   AK
# 2     Arizona   AZ
# 3    Arkansas   AR
# 4  California   CA

# %%
kick = get_kickstarter()

# %% [markdown]
# **Data Cleaning**
#
# - Kept these columns "name","category","subcategory","location","status","goal","funded percentage","backers","duration"
# - Location NaN was changed to Unknown (about 1322 - too big of a sample to drop)
# - Split city and state/country in location

# %%
kick[kick.location.isnull()]
# Out:
#        project id                                               name  \
# 11         727286                       Offline Wikipedia iPhone app
# 14         893085                            Esperanza Farm: A Novel
# 49        2442649  Dream with Me--A documentary about one year in...
# 98        4719237   Indie Music Website (iTunes for Indie Musicians)
# 100       4732285    Insiders/Out: Exploring Outsider Art in America
# 104       4948516  STRANGE POSITIONING SYSTEMS (SPS) - A global l...
# 120       5785733                   Faith - a film by Eli Daughdrill
# 151       7808555  Fabric Fiction: A collaborative literary exper...
# 176       9094253          The People, Places &amp; Patterns Project
# 186       9316432  Produce JigGsaw's never before heard &quot;The...
# 214      10684812  SLEW HAMPSHIRE:  A Tapestry of Transcendental ...
# 244      11603000  Blue Kitabu Gets Sustainable: (Used) Bookstore...
# 45927  http://www.kickstarter.com/projects/1223795292...  Film &amp; Video
# 45928  http://www.kickstarter.com/projects/1223795292...      Film & Video
# 45951  http://www.kickstarter.com/projects/1877936423...        Publishing
#
#               subcategory location      status     goal  pledged  \
# 11          Open Software      NaN  successful     99.0    145.0
# 14                Fiction      NaN      failed   6500.0    765.0
# 49            Documentary      NaN  successful   5000.0   5615.0
# 98             Indie Rock      NaN      failed  10000.0     10.0
# 100                   Art      NaN  successful   2000.0   2000.0
# 104       Performance Art      NaN      failed   8500.0    695.0
# 120      Film &amp; Video      NaN      failed  50000.0   7890.0
# 151               Fiction      NaN      failed   3000.0    582.0
# 176           Photography      NaN      failed  10000.0   3078.0
# 186                  Rock      NaN      failed    700.0     25.0
# 214        Narrative Film      NaN  successful  15000.0  16222.0
# 244            Indie Rock      NaN      failed  10500.0   1240.0
# 255                  Food      NaN  successful   1000.0   1438.0
# 356                 Music      NaN      failed  17000.0    405.0
# 374            Journalism      NaN      failed   1700.0     15.0
# 392           Documentary      NaN      failed   6000.0    940.0
# 393                   Art      NaN      failed   3000.0      0.0
# 397           Photography      NaN      failed   8700.0   3086.0
# 416             Webseries      NaN  successful   5000.0   5630.0
# 483            Short Film      NaN  successful   2000.0   4025.0
# 509                 Music      NaN  successful   3000.0   3079.0
# 636                  Food      NaN      failed   3000.0    355.0
# 719                Crafts      NaN      failed   3000.0    825.0
# 724            Indie Rock      NaN  successful  10000.0  11827.0
# 730                   Art      NaN  successful    600.0    650.0
# 772            Short Film      NaN  successful   8000.0  13716.0
# 811            Publishing      NaN      failed   1000.0    745.0
# 851                 Dance      NaN      failed   1200.0     20.0
# 860              Painting      NaN      failed   3500.0    575.0
# 888           Photography      NaN  successful    500.0   3095.0
# ...                   ...      ...         ...      ...      ...
# 44708         Documentary      NaN  successful   1000.0   1455.0
# 44715  Country &amp; Folk      NaN  successful    100.0    205.0
# 44726         Video Games      NaN      failed   7500.0     10.0
# 44748          Publishing      NaN      failed   1400.0     30.0
# 44781                 Art      NaN  successful   6000.0   6000.0
# 44805    Film &amp; Video      NaN  successful   2000.0   2156.0
# 44861                Food      NaN      failed   1500.0    150.0
# 44969         Documentary      NaN      failed  10000.0   1405.0
# 44970           Webseries      NaN      failed    500.0     15.0
# 45031          Indie Rock      NaN  successful   2000.0   4455.0
# 45066          Indie Rock      NaN  successful   5000.0   6595.0
# 45128          Short Film      NaN      failed   3545.0    220.0
# 45165         Documentary      NaN      failed   4400.0      0.0
# 45188         Documentary      NaN  successful   5000.0   5271.0
# 45232            Painting      NaN  successful   6400.0   6528.0
# 45271         Photography      NaN      failed   3000.0     25.0
# 45437     Children's Book      NaN      failed  10000.0    177.0
# 45535          Indie Rock      NaN  successful   2500.0   2720.0
# 45560  Country &amp; Folk      NaN  successful   7500.0   7684.0
# 45615                Food      NaN      failed   6000.0    176.0
# 45636          Indie Rock      NaN      failed   3000.0      0.0
# 45753          Short Film      NaN  successful  20000.0  20841.0
# 45754          Short Film      NaN  successful  20000.0  20841.0
# 45789         Video Games      NaN  successful  10000.0  11201.0
# 45790         Video Games      NaN  successful  10000.0  11201.0
# 44970           0.030000        1  Thu, 24 Jun 2010 04:59:00 -0000       7
# 45031           2.227720       41  Mon, 01 Feb 2010 19:06:00 -0000      10
# 45066           1.319000       87  Mon, 03 May 2010 04:00:00 -0000       6
# 45128           0.062059        6  Wed, 01 Sep 2010 03:59:00 -0000       8
# 45165           0.000000        0  Thu, 26 Aug 2010 21:19:00 -0000       1
# 45188           1.054200       81  Sun, 18 Jul 2010 09:40:00 -0000       6
# 45232           1.020000       28  Sun, 13 Jun 2010 19:18:00 -0000       8
# 45271           0.008333        1  Sat, 14 Aug 2010 19:34:00 -0000       9
# 45437           0.017743        6  Fri, 16 Oct 2009 09:00:00 -0000       8
# 45535           1.088000       52  Thu, 06 May 2010 03:59:00 -0000       8
# 45560           1.024533       77  Sun, 13 Sep 2009 21:00:00 -0000      15
# 45615           0.029355       17  Fri, 09 Jul 2010 06:05:00 -0000       9
# 45636           0.000000        0  Tue, 31 Aug 2010 16:30:00 -0000       7
# 45753           1.042051      178  Fri, 05 Mar 2010 05:00:00 -0000       8
# 45754           1.042051      178  Fri, 05 Mar 2010 05:00:00 -0000       8
# 45789           1.120056      229  Tue, 23 Mar 2010 05:38:00 -0000       8
# 45790           1.120056      229  Tue, 23 Mar 2010 05:38:00 -0000       8
# 45809           0.000000        0  Thu, 16 Sep 2010 20:03:49 -0000       2
# 45810           0.000000        0  Thu, 16 Sep 2010 20:03:49 -0000       2
# 45927           0.063714        6  Sun, 03 Oct 2010 04:00:00 -0000       7
# 45928           0.063714        6  Sun, 03 Oct 2010 04:00:00 -0000       7
# 45951           2.142857       41  Wed, 01 Jul 2009 05:00:00 -0000       0
#
#                                            reward levels  updates  comments  \
# 11                                                    $1        5        19
# 14                          $5,$10,$25,$50,$75,$150,$300       10         0
# 49            $10,$25,$50,$100,$500,$1,000,$2,500,$5,000        6         7
# 98                                           $1,$20,$100        0         0
# 100    $1,$5,$10,$15,$20,$25,$35,$50,$75,$100,$150,$2...        4         1
# 104    $10,$25,$50,$75,$100,$250,$500,$600,$1,000,$1,500        3         1
# 120             $10,$25,$50,$100,$250,$500,$1,000,$5,000        8         2
# 151               $1,$5,$10,$12,$20,$25,$40,$50,$75,$100        7         0
# 176        $30,$60,$80,$100,$150,$250,$500,$1,000,$2,000       11         6
# 186                         $15,$25,$50,$100,$500,$1,000        0         0
# 214          $5,$13,$26,$55,$106,$245,$500,$1,000,$5,000        8         0
# 244    $2,$5,$10,$15,$35,$75,$100,$150,$250,$500,$1,0...        5         3
# 255                                           $5,$20,$50        0         1
# 356                     $5,$25,$50,$100,$250,$500,$1,500        0         0
# 374                                                  $50        0         0
# 392             $15,$30,$50,$100,$300,$500,$1,000,$5,000        0         0
# 393                        $15,$25,$100,$200,$500,$1,000        0         0
# 397                 $10,$19,$25,$59,$97,$250,$500,$5,000       14         8
# 416                    $5,$10,$25,$50,$250,$1,000,$2,500        2         1
# 483                           $1,$15,$25,$50,$100,$1,000       10         1
# 509                          $3,$5,$15,$25,$50,$100,$250        0         0
# 636                                                   $5        1         3
# 719                           $5,$15,$25,$85,$110,$1,500        0         0
# 724    $1,$15,$25,$50,$100,$200,$500,$1,000,$2,000,$3...       21        21
# 730                            $5,$25,$50,$200,$400,$500        3         0
# 772    $10,$25,$50,$75,$100,$250,$500,$1,000,$2,500,$...        6         2
# 811               $1,$5,$10,$15,$20,$25,$30,$50,$75,$150        4         3
# 851                      $1,$6,$26,$100,$250,$500,$1,000        1         0
# 860                                           $5,$35,$45        0         9
# 888                               $1,$35,$75,$125,$2,500        1         2
# ...                                                  ...      ...       ...
# 44708                      $5,$10,$25,$50,$150,$175,$250       14         1
# 44715               $2,$5,$15,$30,$50,$80,$100,$150,$300        6         3
# 44726                               $5,$10,$50,$100,$500        0         0
# 44748          $5,$14,$22,$66,$111,$333,$444,$666,$1,111        0         0
# 44781                  $2,$10,$20,$40,$80,$150,$250,$400       11        22
# 44805                              $10,$25,$50,$100,$250        2         3
# 44861                        $2,$5,$10,$25,$50,$100,$500        0         0
# 44969  $5,$10,$20,$35,$50,$75,$75,$85,$175,$250,$375,...        3         0
# 44970                         $1,$5,$15,$25,$50,$75,$100        0         0
# 45031    $5,$10,$20,$35,$50,$100,$250,$500,$1,000,$5,000        3         2
# 45066                       $10,$25,$50,$100,$500,$1,000       12         5
# 45128               $5,$10,$25,$50,$100,$250,$500,$1,000        1         1
# 45165                                                 $5        0         0
# 45188                       $10,$25,$50,$100,$500,$5,000        0         2
# 45232                   $1,$5,$10,$20,$50,$118,$258,$518        7         0
# 45271        $5,$15,$25,$50,$100,$250,$500,$1,000,$3,000        0         0
# 45437               $5,$10,$25,$50,$100,$300,$500,$1,000        3         0
# 45535               $5,$10,$25,$50,$100,$250,$500,$1,000       14        10
# 45560  $5,$10,$25,$35,$50,$100,$250,$500,$750,$1,000,...        9         6
# 45615      $5,$10,$25,$50,$100,$250,$1,000,$2,500,$5,000        2         7
# 45636                        $1,$5,$15,$30,$50,$100,$200        0         0
# 45753        $25,$50,$100,$250,$500,$1,000,$2,500,$5,000       10         3
# 45754        $25,$50,$100,$250,$500,$1,000,$2,500,$5,000       10         3
# 45789           $10,$25,$50,$100,$250,$500,$1,000,$2,500       26        18
# 45790           $10,$25,$50,$100,$250,$500,$1,000,$2,500       26        18
# 45809                                           $25,$500        0         0
# 45810                                           $25,$500        0         0
# 45927                    $5,$10,$25,$50,$100,$500,$1,000        1         0
# 45928                    $5,$10,$25,$50,$100,$500,$1,000        1         0
# 45951                                                NaN        3        10
#
#        duration
# 11        79.64
# 14        60.34
# 49        30.89
# 98        29.98
# 100       42.97
# 104       42.19
# 120       74.39
# 151       89.94
# 176       61.67
# 186       89.78
# 214       28.03
# 244       67.22
# 255       34.56
# 356       50.25
# 374       30.00
# 392       50.98
# 393       10.58
# 397       86.96
# 416       32.19
# 483       45.00
# 509       29.91
# 636       31.88
# 719       89.47
# 724       65.48
# 730       53.29
# 772       42.16
# 811       50.39
# 851       49.96
# 860       30.94
# 888       27.94
# ...         ...
# 44708     85.99
# 44715     45.39
# 44726     45.94
# 44748     29.05
# 44781     56.90
# 44805     64.96
# 44861     20.32
# 44969     89.87
# 44970     31.19
# 45031     81.96
# 45066     28.02
# 45128     48.46
# 45165     30.86
# 45188     38.48
# 45232     10.28
# 45271     37.08
# 45437     51.53
# 45535     89.90
# 45560     89.71
# 45615     29.98
# 45636     47.11
# 45753      8.28
# 45754      8.28
# 45789     30.46
# 45790     30.46
# 45809     30.00
# 45810     30.00
# 45927     60.99
# 45928     60.99
# 45951     61.99
#
# [1322 rows x 17 columns]

# %%
kick.isnull().sum()
# Out:
# project id              0
# name                    0
# url                     0
# category                0
# subcategory             0
# location             1322
# status                  0
# goal                    0
# pledged                12
# funded percentage       0
# backers                 0
# funded date             0
# levels                  0
# reward levels          59
# updates                 0
# comments                0
# duration                0
# dtype: int64

# %%
kick[["city","origin"]] = kick["location"].str.split(', ', n=1, expand=True)
# df[["city","state-country"]] = df["location"].str.split(',', n=1, expand=True)
#     df = df.drop(["location"],axis=1)
#     return df

# %%
list(kick.origin.unique())
# Out:
# ['MO',
#  'NJ',
#  'CA',
#  'MI',
#  'OR',
#  'TN',
#  'IL',
#  nan,
#  'NY',
#  'DC',
#  'NE',
#  'ID',
#  'FL',
#  'TX',
#  'CO',
#  'ME',
#  'Taiwan',
#  'IN',
#  'OH',
#  'Norway',
#  'MA',
#  'MN',
#  'PA',
#  'NC',
#  'WV',
#  'CT',
#  'Chile',
#  'MD',
#  'HI',
#  'VA',
#  'WA',
#  'AZ',
#  'OK',
#  'NV',
#  'Haiti',
#  'GA',
#  'AL',
#  'UT',
#  'Canada',
#  'LA',
#  'SC',
#  'Ecuador',
#  'WI',
#  'Jamaica',
#  'Argentina',
#  'Hong Kong',
#  'Germany',
#  'NM',
#  'Guatemala',
#  'NH',
#  'IA',
#  'WY',
#  'Australia',
#  'RI',
#  'Sweden',
#  'France',
#  'DE',
#  'South Africa',
#  'AK',
#  'Nepal',
#  'MT',
#  'KY',
#  'VT',
#  'Kenya',
#  'Bosnia and Herzegovina',
#  'Iceland',
#  'Mexico',
#  'KS',
#  'Hungary',
#  'Indonesia',
#  'China',
#  'SD',
#  'Cuba',
#  'Peru',
#  'Italy',
#  'Netherlands',
#  'Singapore',
#  'Ethiopia',
#  'New Zealand',
#  'United Kingdom',
#  'Austria',
#  'Turkey',
#  'AR',
#  'Mt',
#  'Congo',
#  'Colombia',
#  'India',
#  'Mongolia',
#  'MS',
#  'Israel',
#  'Dominica',
#  'Spain',
#  'Finland',
#  'Czech Republic',
#  'Japan',
#  'Virgin Islands, U.S.',
#  'Lebanon',
#  'Armenia',
#  'Portugal',
#  'Qatar',
#  'Morocco',
#  'Martinique',
#  'Puerto Rico',
#  'Afghanistan',
#  'Denmark',
#  'Tanzania',
#  'Kazakhstan',
#  'Zambia',
#  'Switzerland',
#  'Egypt',
#  'Svalbard and Jan Mayen',
#  'ND',
#  'Burkina Faso',
#  'Liberia',
#  'Ghana',
#  'Nicaragua',
#  'Russia',
#  'Ukraine',
#  'Bulgaria',
#  'South Korea',
#  'Brazil',
#  'Rwanda',
#  'Costa Rica',
#  'Philippines',
#  'Pakistan',
#  'El Salvador',
#  'Panama',
#  'United Arab Emirates',
#  'Romania',
#  'Honduras',
#  'Palestinian Territories',
#  'Poland',
#  'Georgia',
#  'Syrian Arab Republic',
#  'Bolivia',
#  'Greece',
#  'Cambodia',
#  'Nigeria',
#  'Mali',
#  'Saudi Arabia',
#  'Argent',
#  'Iraq',
#  'Cameroon',
#  'Namibia',
#  'Ireland',
#  'Venezuela',
#  None,
#  'Thailand',
#  'Jordan',
#  'Tunisia',
#  'Zimbabwe',
#  'Iran',
#  'Sierra Leone',
#  'Isle of Man',
#  'Central African Republic',
#  'Serbia',
#  'Belize',
#  'Uganda',
#  'Malta',
#  'Slovenia',
#  'Sudan',
#  'Belgium',
#  'Myanmar',
#  'Malaysia',
#  'North Korea',
#  'Greenland',
#  'Senegal',
#  'Bahamas',
#  'Malawi',
#  'Mozambique',
#  'Bhutan',
#  'Lithuania',
#  'Micronesia',
#  'Equatorial Guinea',
#  'Tajikistan',
#  'Kyoto, Japan',
#  'Sri Lanka',
#  'Libyan Arab Jamahiriya',
#  'Guinea',
#  'Bermuda',
#  'Belarus',
#  'Estonia',
#  'Suriname',
#  'Dominican Republic',
#  'Vanuatu',
#  'Trinidad and Tobago',
#  'Cyprus',
#  'Macedonia',
#  'Viet Nam',
#  'Scotland, United Kingdom',
#  'Barbados',
#  'Swaziland',
#  'Falkland Islands',
#  'Kyrgyzstan',
#  'Bangladesh',
#  'Laos',
#  'Middleburg, MD',
#  'Papua New Guinea',
#  'Virginia',
#  'Uruguay',
#  'Guam',
#  'Dominican Re',
#  'Saint Lucia']

# %%
kick.groupby("origin").count()
# Out:
#                           project id  name   url  category  subcategory  \
# origin
# AK                               110   110   110       110          110
# AL                               166   166   166       166          166
# AR                               106   106   106       106          106
# AZ                               649   649   649       649          649
# Afghanistan                       16    16    16        16           16
# Argent                             4     4     4         4            4
# Argentina                         29    29    29        29           29
# Armenia                            5     5     5         5            5
# Australia                         57    57    57        57           57
# Austria                           19    19    19        19           19
# Bahamas                            1     1     1         1            1
# Bangladesh                         2     2     2         2            2
# Barbados                           1     1     1         1            1
# Belarus                            3     3     3         3            3
# Belgium                            5     5     5         5            5
# Belize                             6     6     6         6            6
# Bermuda                            1     1     1         1            1
# Bhutan                             3     3     3         3            3
# Bolivia                           10    10    10        10           10
# Bosnia and Herzegovina             9     9     9         9            9
# Brazil                            38    38    38        38           38
# Bulgaria                           4     4     4         4            4
# Burkina Faso                       1     1     1         1            1
# CA                              8973  8973  8973      8973         8973
# CO                               807   807   807       807          807
# CT                               328   328   328       328          328
# Cambodia                          14    14    14        14           14
# Cameroon                           2     2     2         2            2
# Canada                           284   284   284       284          284
# Central African Republic           1     1     1         1            1
# ...                              ...   ...   ...       ...          ...
# Switzerland                       10    10    10        10           10
# Syrian Arab Republic               2     2     2         2            2
# TN                              1017  1017  1017      1017         1017
# TX                              2056  2056  2056      2056         2056
# Taiwan                            12    12    12        12           12
# Tajikistan                         1     1     1         1            1
# Tanzania                          14    14    14        14           14
# Thailand                          25    25    25        25           25
# Trinidad and Tobago                2     2     2         2            2
# Tunisia                            5     5     5         5            5
# Turkey                            19    19    19        19           19
# UT                               437   437   437       437          437
# Uganda                            13    13    13        13           13
# Ukraine                            7     7     7         7            7
# United Arab Emirates               5     5     5         5            5
# United Kingdom                   215   215   215       215          215
# Uruguay                            1     1     1         1            1
# VA                               556   556   556       556          556
# VT                               187   187   187       187          187
# Vanuatu                            2     2     2         2            2
# Venezuela                          4     4     4         4            4
# Viet Nam                           5     5     5         5            5
# Virgin Islands, U.S.               2     2     2         2            2
# Virginia                           1     1     1         1            1
# WA                              1426  1426  1426      1426         1426
# WI                               397   397   397       397          397
# WV                                68    68    68        68           68
# WY                                31    31    31        31           31
# Zambia                             3     3     3         3            3
# Zimbabwe                           4     4     4         4            4
#
#                           location  status  goal  pledged  funded percentage  \
# origin
# AK                             110     110   110      110                110
# AL                             166     166   166      166                166
# AR                             106     106   106      106                106
# AZ                             649     649   649      649                649
# Afghanistan                     16      16    16       16                 16
# Argent                           4       4     4        4                  4
# Argentina                       29      29    29       29                 29
# Armenia                          5       5     5        5                  5
# Australia                       57      57    57       57                 57
# Austria                         19      19    19       19                 19
# Bahamas                          1       1     1        1                  1
# Bangladesh                       2       2     2        2                  2
# Barbados                         1       1     1        1                  1
# Belarus                          3       3     3        3                  3
# Belgium                          5       5     5        5                  5
# Belize                           6       6     6        6                  6
# Bermuda                          1       1     1        1                  1
# Bhutan                           3       3     3        3                  3
# Bolivia                         10      10    10       10                 10
# Bosnia and Herzegovina           9       9     9        9                  9
# Brazil                          38      38    38       38                 38
# Bulgaria                         4       4     4        4                  4
# Burkina Faso                     1       1     1        1                  1
# CA                            8973    8973  8973     8968               8973
# CO                             807     807   807      807                807
# CT                             328     328   328      328                328
# Cambodia                        14      14    14       14                 14
# Cameroon                         2       2     2        2                  2
# Canada                         284     284   284      284                284
# Central African Republic         1       1     1        1                  1
# ...                            ...     ...   ...      ...                ...
# Switzerland                     10      10    10       10                 10
# Syrian Arab Republic             2       2     2        2                  2
# TN                            1017    1017  1017     1017               1017
# TX                            2056    2056  2056     2056               2056
# Taiwan                          12      12    12       12                 12
# Tajikistan                       1       1     1        1                  1
# Tanzania                        14      14    14       14                 14
# Thailand                        25      25    25       25                 25
# Trinidad and Tobago              2       2     2        2                  2
# Tunisia                          5       5     5        5                  5
# Turkey                          19      19    19       19                 19
# UT                             437     437   437      437                437
# Uganda                          13      13    13       13                 13
# Ukraine                          7       7     7        7                  7
# United Arab Emirates             5       5     5        5                  5
# United Kingdom                 215     215   215      214                215
# Uruguay                          1       1     1        1                  1
# VA                             556     556   556      556                556
# VT                             187     187   187      187                187
# Vanuatu                          2       2     2        2                  2
# Venezuela                        4       4     4        4                  4
# Viet Nam                         5       5     5        5                  5
# Virgin Islands, U.S.             2       2     2        2                  2
# Virginia                         1       1     1        1                  1
# WA                            1426    1426  1426     1426               1426
# WI                             397     397   397      397                397
# WV                              68      68    68       68                 68
# WY                              31      31    31       31                 31
# Zambia                           3       3     3        3                  3
# Zimbabwe                         4       4     4        4                  4
#
#                           backers  funded date  levels  reward levels  \
# origin
# AK                            110          110     110            110
# AL                            166          166     166            166
# AR                            106          106     106            106
# AZ                            649          649     649            649
# Afghanistan                    16           16      16             16
# Argent                          4            4       4              4
# Argentina                      29           29      29             29
# Armenia                         5            5       5              5
# Australia                      57           57      57             57
# Austria                        19           19      19             19
# Bahamas                         1            1       1              1
# Bangladesh                      2            2       2              2
# Barbados                        1            1       1              1
# Belarus                         3            3       3              3
# Belgium                         5            5       5              5
# Belize                          6            6       6              6
# Bermuda                         1            1       1              1
# Bhutan                          3            3       3              3
# Bolivia                        10           10      10             10
# Bosnia and Herzegovina          9            9       9              9
# Brazil                         38           38      38             38
# Bulgaria                        4            4       4              4
# Burkina Faso                    1            1       1              1
# CA                           8973         8973    8973           8966
# CO                            807          807     807            807
# CT                            328          328     328            328
# Cambodia                       14           14      14             14
# Cameroon                        2            2       2              2
# Canada                        284          284     284            284
# Central African Republic        1            1       1              1
# ...                           ...          ...     ...            ...
# Switzerland                    10           10      10             10
# Syrian Arab Republic            2            2       2              2
# TN                           1017         1017    1017           1017
# TX                           2056         2056    2056           2055
# Taiwan                         12           12      12             12
# Tajikistan                      1            1       1              1
# Tanzania                       14           14      14             14
# Thailand                       25           25      25             25
# Trinidad and Tobago             2            2       2              2
# Tunisia                         5            5       5              5
# Turkey                         19           19      19             19
# UT                            437          437     437            437
# Uganda                         13           13      13             13
# Ukraine                         7            7       7              7
# United Arab Emirates            5            5       5              5
# United Kingdom                215          215     215            215
# Uruguay                         1            1       1              1
# VA                            556          556     556            556
# VT                            187          187     187            187
# Vanuatu                         2            2       2              2
# Venezuela                       4            4       4              4
# Viet Nam                        5            5       5              5
# Virgin Islands, U.S.            2            2       2              2
# Virginia                        1            1       1              1
# WA                           1426         1426    1426           1425
# WI                            397          397     397            397
# WV                             68           68      68             68
# WY                             31           31      31             31
# Zambia                          3            3       3              3
# Zimbabwe                        4            4       4              4
#
#                           updates  comments  duration  extra  city
# origin
# AK                            110       110       110    110   110
# AL                            166       166       166    166   166
# AR                            106       106       106    106   106
# AZ                            649       649       649    649   649
# Afghanistan                    16        16        16     16    16
# Argent                          4         4         4      4     4
# Argentina                      29        29        29     29    29
# Armenia                         5         5         5      5     5
# Australia                      57        57        57     57    57
# Austria                        19        19        19     19    19
# Bahamas                         1         1         1      1     1
# Bangladesh                      2         2         2      2     2
# Barbados                        1         1         1      1     1
# Belarus                         3         3         3      3     3
# Belgium                         5         5         5      5     5
# Belize                          6         6         6      6     6
# Bermuda                         1         1         1      1     1
# Bhutan                          3         3         3      3     3
# Bolivia                        10        10        10     10    10
# Bosnia and Herzegovina          9         9         9      9     9
# Brazil                         38        38        38     38    38
# Bulgaria                        4         4         4      4     4
# Burkina Faso                    1         1         1      1     1
# CA                           8973      8973      8973   8973  8973
# CO                            807       807       807    807   807
# CT                            328       328       328    328   328
# Cambodia                       14        14        14     14    14
# Cameroon                        2         2         2      2     2
# Canada                        284       284       284    284   284
# Central African Republic        1         1         1      1     1
# ...                           ...       ...       ...    ...   ...
# Switzerland                    10        10        10     10    10
# Syrian Arab Republic            2         2         2      2     2
# TN                           1017      1017      1017   1017  1017
# TX                           2056      2056      2056   2056  2056
# Taiwan                         12        12        12     12    12
# Tajikistan                      1         1         1      1     1
# Tanzania                       14        14        14     14    14
# Thailand                       25        25        25     25    25
# Trinidad and Tobago             2         2         2      2     2
# Tunisia                         5         5         5      5     5
# Turkey                         19        19        19     19    19
# UT                            437       437       437    437   437
# Uganda                         13        13        13     13    13
# Ukraine                         7         7         7      7     7
# United Arab Emirates            5         5         5      5     5
# United Kingdom                215       215       215    215   215
# Uruguay                         1         1         1      1     1
# VA                            556       556       556    556   556
# VT                            187       187       187    187   187
# Vanuatu                         2         2         2      2     2
# Venezuela                       4         4         4      4     4
# Viet Nam                        5         5         5      5     5
# Virgin Islands, U.S.            2         2         2      2     2
# Virginia                        1         1         1      1     1
# WA                           1426      1426      1426   1426  1426
# WI                            397       397       397    397   397
# WV                             68        68        68     68    68
# WY                             31        31        31     31    31
# Zambia                          3         3         3      3     3
# Zimbabwe                        4         4         4      4     4
#
# [201 rows x 19 columns]

# %% [markdown]
# Unusual Origins:
# - None
# - Argent?
# - Mt >> Montana
# - nan
# - Kyoto, Japan (as origin, drop Kyoto)
# - Dominican Re, Dominican Republic
# -
#
# **TASKS**
# - Change Mt to Montana (36 entries)
# - Change Argent to Argentina

# %%
org.head()
# Out:
#            origin continent       sub_region
# 0     Afghanistan      Asia    Southern Asia
# 1   Åland Islands    Europe  Northern Europe
# 2         Albania    Europe  Southern Europe
# 3         Algeria    Africa  Northern Africa
# 4  American Samoa   Oceania        Polynesia

# %%
kick.join(org, on="origin")
# Out:
# -----------------------------------------------------------------------
# KeyError                              Traceback (most recent call last)
# <ipython-input-86-873aba44b9d5> in <module>
# ----> 1 kick.join(org, on="origin")
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    6813         # For SparseDataFrame's benefit
#    6814         return self._join_compat(other, on=on, how=how, lsuffix=lsuffix,
# -> 6815                                  rsuffix=rsuffix, sort=sort)
#    6816
#    6817     def _join_compat(self, other, on=None, how='left', lsuffix='', rsuffix='',
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    6828             return merge(self, other, left_on=on, how=how,
#    6829                          left_index=on is None, right_index=True,
# -> 6830                          suffixes=(lsuffix, rsuffix), sort=sort)
#    6831         else:
#    6832             if on is not None:
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      45                          right_index=right_index, sort=sort, suffixes=suffixes,
#      46                          copy=copy, indicator=indicator,
# ---> 47                          validate=validate)
#      48     return op.get_result()
#      49
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     527         (self.left_join_keys,
#     528          self.right_join_keys,
# --> 529          self.join_names) = self._get_merge_keys()
#     530
#     531         # validate the merge keys dtypes. We may need to coerce
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/merge.py in _get_merge_keys(self)
#     856                     join_names.append(None)
#     857                 else:
# --> 858                     left_keys.append(left._get_label_or_level_values(k))
#     859                     join_names.append(k)
#     860             if isinstance(self.right.index, MultiIndex):
#
# /usr/local/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1704             values = self.axes[axis].get_level_values(key)._values
#    1705         else:
# -> 1706             raise KeyError(key)
#    1707
#    1708         # Check for duplicates
#
# KeyError: 'origin'
